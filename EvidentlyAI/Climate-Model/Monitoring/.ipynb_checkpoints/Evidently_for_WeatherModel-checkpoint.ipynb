# %% [markdown]
# <a href="https://colab.research.google.com/github/mfligiel/Models-for-MLOPS-Review/blob/main/Evidently_for_WeatherModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Weather Data
#
# I am going to predict Chicago's weather from the weather of 5 other places nearby using a weather API.  This model isn't the most useful, but is good for showcasing model monitoring.
#
# Here, I will pull in some June data, but replacing Toronto with Phoenix.  A bit of a different temperature distribution!

# %%
# !pip install evidently
# Out:
# Collecting evidently
#   Downloading https://files.pythonhosted.org/packages/8b/64/817e8fb176d8393eb2b49f5650957e7ddb11dc3f9d531deb9e26036f8553/evidently-0.1.19.dev0-py3-none-any.whl (15.2MB)
#      |████████████████████████████████| 15.2MB 199kB/s
# Requirement already satisfied: scikit-learn>=0.22.1 in /usr/local/lib/python3.7/dist-packages (from evidently) (0.22.2.post1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (from evidently) (4.4.1)
# Collecting dataclasses
#   Downloading https://files.pythonhosted.org/packages/26/2f/1095cdc2868052dd1e64520f7c0d5c8c550ad297e944e641dbf1ffbb9a5d/dataclasses-0.6-py3-none-any.whl
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from evidently) (1.1.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from evidently) (3.13)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.7/dist-packages (from evidently) (0.10.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from evidently) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from evidently) (1.19.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.1->evidently) (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly->evidently) (1.15.0)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.7/dist-packages (from plotly->evidently) (1.3.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->evidently) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->evidently) (2018.9)
# Requirement already satisfied: patsy>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from statsmodels->evidently) (0.5.1)
# Installing collected packages: dataclasses, evidently
# Successfully installed dataclasses-0.6 evidently-0.1.19.dev0

# %%
import requests
import pandas as pd
import time
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
import evidently
from evidently.dashboard import Dashboard
from evidently.tabs import DataDriftTab, NumTargetDriftTab, RegressionPerformanceTab
from IPython.display import IFrame
import pickle

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# This should work!  I'll now find the IDs of 5 cities I will use to predict Chicago's weather:
#
# Milwaukee\
# Detroit\
# Toronto\
# St Louis\
# Omaha, NE
#
#
# I'll use this site to look it up: https://www.findmecity.com/
#
# Milwaukee: 2451822\
# Detroit: 2391585 \
# Toronto: 4118\
# St. Louis: 2486982\
# Omaha, NE: 2465512
#
# I'll switch Toronto's WOEID for that of Phoenix: 2471390
#
# I'll run this once, and then comment it out for now.

# %%
# #dictionary of cities
# cities = {'Milwaukee':'2451822', 'Detroit':'2391585', 'Toronto':'2471390', 'St. Louis':'2486982', 'Omaha':'2465512', 'Chicago':'2379574'} #phoenix for toronto

# #empty list to enter these into:
# values = []

# #loop through cities
# for k, v in cities.items():
#   #loop through 3 months
#   for mth in ['6']:
#     #just do days through 30, it's not time series, I don't care
#     for day in range(1, 15):
#       #what to request
#       strng = 'https://www.metaweather.com/api/location/' + v +'/2021/' + mth + '/' +str(day) + '/'
#       if day == 1:
#         print(strng)
#       reqst = requests.get(strng)
#       #get the pieces
#       date = pd.to_datetime(pd.DataFrame(reqst.json()).max()['created']).date()
#       maxtemp = pd.DataFrame(reqst.json()).max()['max_temp']
#       values.append([k, date, maxtemp])
#       time.sleep(3)

# %%
#pd.DataFrame(values).to_csv('Test.csv')

# %%
#!ls

# %%
#!cp Test.csv gdrive/MyDrive

# %% [markdown]
# ## Loading in this data (once saved), and the model
#
# Now I can prep to predict, and see how different it really is.

# %%
#load in data
df = pd.read_csv(r'/content/gdrive/MyDrive/ModelMonitoringBlog/Test.csv')
#load in model
model = pickle.load(open(r'/content/gdrive/MyDrive/ModelMonitoringBlog/weather_model.pkl', 'rb'))

# %%
#Now, to rename the columns
df.columns = ['drp', 'city', 'date', 'maxtemp']
df.drop('drp', axis=1, inplace=True)

# %%
#reshape the data
df = df.pivot(index='date', columns='city', values='maxtemp')

# %%
df.head()
# Out:
# city        Chicago  Detroit  Milwaukee   Omaha  St. Louis  Toronto
# date
# 2021-06-02   23.700   25.790      23.15  26.060     29.230   40.120
# 2021-06-03   24.420   24.910      22.73  27.475     28.090   41.715
# 2021-06-04   28.055   26.210      28.65  29.965     28.675   41.960
# 2021-06-05   30.675   30.885      31.51  33.610     30.565   42.410
# 2021-06-06   31.375   31.790      31.80  33.165     33.330   42.070

# %% [markdown]
# Let's make a prediction.

# %%
predictions = model.predict(df.drop('Chicago', axis=1))

# %%
df['Chicago'] - predictions
# Out:
# date
# 2021-06-02    0.252094
# 2021-06-03    1.663958
# 2021-06-04    1.463601
# 2021-06-05    0.412679
# 2021-06-06    0.194342
# 2021-06-07    1.332528
# 2021-06-08    0.825372
# 2021-06-09    0.262758
# 2021-06-10   -1.233267
# 2021-06-11   -0.465028
# 2021-06-12   -0.681110
# 2021-06-13   -0.408895
# 2021-06-14   -0.015240
# 2021-06-15    0.750277
# Name: Chicago, dtype: float64

# %% [markdown]
# ## Evidently
#
# In order to generate reports, I will need to load in the old data:

# %%
#re creating the dictionary above 
cities = {'Milwaukee':'2451822', 'Detroit':'2391585', 'Toronto':'4118', 'St. Louis':'2486982', 'Omaha':'2465512', 'Chicago':'2379574'}

df_old = pd.DataFrame()

for i in cities.keys():
  if i == 'St. Louis':
    i = 'St_Louis'
  pth = "gdrive/MyDrive/ModelMonitoringBlog/" + i + ".csv"
  print(pth)
  to_append = pd.read_csv(pth)
  #print(to_append.head())
  if df_old.empty:
    df_old = to_append
    print(df_old.empty)
  else:
    df_old = pd.concat([df_old, to_append], ignore_index=True)
# Out:
# gdrive/MyDrive/ModelMonitoringBlog/Milwaukee.csv
# False
# gdrive/MyDrive/ModelMonitoringBlog/Detroit.csv
# gdrive/MyDrive/ModelMonitoringBlog/Toronto.csv
# gdrive/MyDrive/ModelMonitoringBlog/St_Louis.csv
# gdrive/MyDrive/ModelMonitoringBlog/Omaha.csv
# gdrive/MyDrive/ModelMonitoringBlog/Chicago.csv

# %%
#Now, to rename the columns
df_old.columns = ['drp', 'city', 'date', 'maxtemp']
df_old.drop('drp', axis=1, inplace=True)
df_old = df_old.pivot(index='date', columns='city', values='maxtemp')

# %%
weather_data_drift_report = Dashboard(tabs=[DataDriftTab])
weather_data_drift_report.calculate(df_old.drop('Chicago', axis=1), df.drop('Chicago', axis=1), column_mapping = None)
weather_data_drift_report.save("gdrive/MyDrive/ModelMonitoringBlog/reports/my_report_with_2_tabs.html")

# %% [markdown]
# Even though this code is almost directly from their example, I had to find where CatTargetDriftTab is (though I quickly remembered it wasn't applicable with this data).  This does seem super easy!  But it does seem like you'd need some old data, so this wouldn't necessarily be great for an ongoing use case.
#
# Also, as I am (possibly?) on windows in Colab, I cannot directly build this in the notebook.

# %%
IFrame(src="gdrive/MyDrive/ModelMonitoringBlog/reports/my_report_with_2_tabs.html", width=700, height=600)
# Out:
#         <iframe
#             width="700"
#             height="600"
#             src="gdrive/MyDrive/ModelMonitoringBlog/reports/my_report_with_2_tabs.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# It seems to detect an issue in each one, which makes sense, as it is comparing June to other months.  I will look later at taking a sample from Feb-May of the previous year to predict.  However, it only says if drift is detected or not detected, and the charts do leave some room for interpretation - it isn't always clear what the axes of each are!

# %%
# #dictionary of cities
# cities = {'Milwaukee':'2451822', 'Detroit':'2391585', 'Toronto':'2471390', 'St. Louis':'2486982', 'Omaha':'2465512', 'Chicago':'2379574'} #phoenix for toronto

# #empty list to enter these into:
# values = []

# #loop through cities
# for k, v in cities.items():
#   #loop through 3 months
#   for mth in ['3','4','5']:
#     #just do days through 10, it's not time series, I don't care
#     for day in range(1, 10):
#       #what to request
#       strng = 'https://www.metaweather.com/api/location/' + v +'/2020/' + mth + '/' +str(day) + '/'
#       if day == 1:
#         print(strng)
#       reqst = requests.get(strng)
#       #get the pieces
#       date = pd.to_datetime(pd.DataFrame(reqst.json()).max()['created']).date()
#       maxtemp = pd.DataFrame(reqst.json()).max()['max_temp']
#       values.append([k, date, maxtemp])
#       time.sleep(3)


# pd.DataFrame(values).to_csv('Weather2020.csv')

# %%
#!ls

# %%
#!cp Weather2020.csv gdrive/MyDrive/ModelMonitoringBlog/

# %% [markdown]
# Now I can load this in and compare it.

# %%
w2020 = pd.read_csv(r'/content/gdrive/MyDrive/ModelMonitoringBlog/Weather2020.csv')
#Now, to rename the columns
w2020.columns = ['drp', 'city', 'date', 'maxtemp']
w2020.drop('drp', axis=1, inplace=True)
w2020 = w2020.pivot(index='date', columns='city', values='maxtemp')

# %%
w2020
# Out:
# city        Chicago  Detroit  Milwaukee   Omaha  St. Louis  Toronto
# date
# 2020-03-02   11.605    6.565     11.400  16.785     19.720   26.570
# 2020-03-03    8.580   11.250      8.015  14.060     20.145   22.890
# 2020-03-04    8.410   11.735      8.635  15.215     18.690   24.455
# 2020-03-05    9.310   11.615      9.545  16.970     18.040   24.730
# 2020-03-06   11.425   12.675     11.955  19.195     20.020   28.780
# 2020-03-07    8.460   10.090     12.340  20.550     18.970   29.850
# 2020-03-08   10.005    7.830     11.605  21.255     17.450   28.520
# 2020-03-09   16.635   15.340     15.610  21.760     21.100   25.510
# 2020-03-10   12.425   17.650     13.680  17.890     17.335   26.510
# 2020-04-02   11.280   17.280     14.070  22.920     20.780   31.070
# 2020-04-03   13.160   15.250     12.310  20.970     20.510   30.515
# 2020-04-04   17.600   15.765     14.505  20.070     21.000   32.025
# 2020-04-05   13.680   16.550     13.390  12.860     16.890   32.140
# 2020-04-06   13.000   16.300     14.060  18.145     20.825   31.390
# 2020-04-07   16.400   17.495     16.650  25.035     25.845   29.270
# 2020-04-08   24.260   21.460     21.500  29.295     29.370   28.705
# 2020-04-09   19.420   21.985     20.160  25.950     31.405   27.150
# 2020-04-10   20.230   21.430     21.610  18.725     24.740   24.170
# 2020-05-02   19.980   18.225     22.790  31.505     26.500   39.260
# 2020-05-03   23.260   23.815     23.890  26.460     30.175   38.040
# 2020-05-04   20.755   23.390     21.165  24.910     29.180   37.840
# 2020-05-05   18.340   20.980     21.790  23.340     28.510   36.895
# 2020-05-06   18.340   17.160     12.830  22.005     27.310   38.960
# 2020-05-07   16.925   17.160     16.600  22.215     22.095   41.150
# 2020-05-08   21.250   17.545     20.260  24.850     24.330   41.450
# 2020-05-09   15.780   17.440     15.750  18.640     19.230   40.855
# 2020-05-10   13.560   14.270     13.605  20.010     18.295   40.705

# %%
predictions2020 = model.predict(w2020.drop('Chicago', axis=1))

# %%
w2020['Chicago'] - predictions2020
# Out:
# date
# 2020-03-02    2.516554
# 2020-03-03   -0.376788
# 2020-03-04   -0.795456
# 2020-03-05   -0.340018
# 2020-03-06   -0.153182
# 2020-03-07   -2.308167
# 2020-03-08    0.532318
# 2020-03-09    1.679587
# 2020-03-10   -1.313858
# 2020-04-02   -3.270832
# 2020-04-03    0.390888
# 2020-04-04    3.560140
# 2020-04-05    1.209856
# 2020-04-06   -0.845977
# 2020-04-07   -0.701304
# 2020-04-08    2.302799
# 2020-04-09   -2.187732
# 2020-04-10   -0.423680
# 2020-05-02   -0.688398
# 2020-05-03   -0.204281
# 2020-05-04   -0.852827
# 2020-05-05   -2.593346
# 2020-05-06    3.838542
# 2020-05-07    1.426937
# 2020-05-08    3.128059
# 2020-05-09    1.377549
# 2020-05-10    1.416158
# Name: Chicago, dtype: float64

# %% [markdown]
# Let's look at this with evidently.

# %%
weather_data_drift_report_2 = Dashboard(tabs=[DataDriftTab])
weather_data_drift_report_2.calculate(df_old.drop('Chicago', axis=1), w2020.drop('Chicago', axis=1), column_mapping = None)
weather_data_drift_report_2.save("gdrive/MyDrive/ModelMonitoringBlog/reports/2020_weather_report.html")

# %% [markdown]
# I had to save this in a separate folder and then download to open, since these don't integrate in well.  It seems to use a KS test to analyze drift - let's see what it does for:
#
# - Target shift: is it detecting if we're seeing a difference in our output distribution?
# - Concept shift: this is hard to detect, but could it help us tell if the fundamental concept of the model doesn't quite apply in the same way anymore?
# - Class imbalance: not quite applicable for this model, but could be covered similarly to target shift.
#
# I can directly look at target shift - let's see how it compares my predictions to past ones:

# %%
weather_target_drift_report = Dashboard(tabs=[NumTargetDriftTab])

weather_target_drift_report.calculate(df_old, predictions2020, column_mapping = None)

# %%
weather_target_drift_report.show()
# Out:
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
#   * {
#     all: unset;
#   }
# }
# </style>
# <script>
#     var evidently_dashboard_79c72369b4684d4bb46ac7cea6a31838 = {"name": "evidently_dashboard_79c72369b4684d4bb46ac7cea6a31838", "widgets": []};
#     var additional_graphs_evidently_dashboard_79c72369b4684d4bb46ac7cea6a31838 = {};
# </script>
# <script>
# $(document).ready(function () {
#     requirejs(["evidently"], function(ev) {
#         drawDashboard(evidently_dashboard_79c72369b4684d4bb46ac7cea6a31838,
#         new Map(Object.entries(additional_graphs_evidently_dashboard_79c72369b4684d4bb46ac7cea6a31838)),
#         "root_evidently_dashboard_79c72369b4684d4bb46ac7cea6a31838");
#     },
#     function(err) {
#         $("#root_evidently_dashboard_79c72369b4684d4bb46ac7cea6a31838").innerHTML = "Failed to load";
#     })
# });
# </script>
# <div class="reset-this-parent" id="root_evidently_dashboard_79c72369b4684d4bb46ac7cea6a31838">Loading...</div>

# %% [markdown]
# This just shows 'loading.'

# %%
weather_target_drift_report.save("gdrive/MyDrive/ModelMonitoringBlog/reports/2020_weather_TARGET_report.html")

# %% [markdown]
# This didn't work.  Let me retry with the chicago column as a df.., and their recommended column mapping.  Not a ton of documentation here.

# %%
df_old.columns
# Out:
# Index(['Chicago', 'Detroit', 'Milwaukee', 'Omaha', 'St. Louis', 'Toronto'], dtype='object', name='city')

# %%
target = 'Chicago'
prediction = 'prediction'
numerical_features = ['Detroit', 'Milwaukee', 'Omaha', 'St. Louis', 'Toronto']
#no categorical features
#categorical_features = ['season', 'holiday', 'workingday']

#reference = raw_data.loc['2011-01-01 00:00:00':'2011-01-28 23:00:00']
#current = raw_data.loc['2011-01-29 00:00:00':'2011-02-28 23:00:00']

column_mapping = {}

column_mapping['target'] = target
column_mapping['prediction'] = predictions
#column_mapping['numerical_features'] = numerical_features
#column_mapping['categorical_features'] = categorical_features

# %% [markdown]
# Also, let me add in the predictions to the test dataframe....and it needs predictions for the original too.

# %%
w2020_preds = w2020.copy()
w2020_preds['prediction'] = predictions2020
#df_old['prediction'] = model.predict(df_old.drop('Chicago', axis=1))
df_old['prediction'] = model.predict(df_old.drop(['Chicago', 'prediction'], axis=1))

# %%
weather_target_drift_report = Dashboard(tabs=[NumTargetDriftTab])

weather_target_drift_report.calculate(df_old, w2020_preds, column_mapping=None)

# %% [markdown]
# Turns out the column mapping was messing it up...

# %%
weather_target_drift_report.show()
# Out:
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
#   * {
#     all: unset;
#   }
# }
# </style>
# <script>
#     var evidently_dashboard_8f3c10795cb84e9ea4201c4831d57f27 = {"name": "evidently_dashboard_8f3c10795cb84e9ea4201c4831d57f27", "widgets": [{"type": "big_graph", "title": "Prediction Drift: detected, p_value=0.016941", "size": 2, "details": "", "alertsPosition": "row", "alertStats": {}, "params": {"data": [{"autobinx": false, "histnorm": "probability density", "legendgroup": "Reference", "marker": {"color": "#4d4d4d"}, "name": "Reference", "opacity": 0.7, "type": "histogram", "x": [5.114965165581406, 7.423839164139064, 11.107996565418798, 10.763188167207087, 10.194483543497494, 9.556285148007372, 11.395870198342006, 15.184061288190389, 16.137470237439754, 17.917560893298354, 17.603529149570686, 13.270839910091834, 12.614927290799454, 9.991733333911863, 8.021579250607086, 14.223874916863604, 15.30786155797426, 8.196486959590654, 9.699977071654526, 11.205373392699197, 16.01607311434439, 17.52176594320819, 15.764723338213383, 17.042169325605, 14.58012092933033, 16.062099521543853, 14.763967226370351, 12.920731424365822, 15.727348050769006, 19.83186629729057, 14.995441400275507, 13.025067664729018, 20.004830058510787, 21.587720335130722, 22.931092555915892, 24.789287124435997, 22.931756629047367, 22.1725669798747, 19.036584315936107, 17.77780290913118, 18.961740922124488, 20.876029430748257, 17.583492730787167, 13.293816036291812, 13.45074625160002, 13.283826789983404, 13.559263327585793, 14.044748182526444, 16.744854007183857, 14.268788703096629, 13.621084041797982, 14.094378267851564, 15.027439780876346, 17.844237628773794, 18.665587212717423, 21.874032362039895, 26.459464948971696, 24.54354660173068, 20.850006951440985, 19.056894204929886, 25.70014600430407, 27.825851025026463, 25.2125075175051, 22.069543287516534, 18.34670285697815, 16.55180031688091, 16.438307418706284, 15.620369135314075, 16.841527776384833, 15.903394948616334, 15.875818423148399, 15.876833413455653, 17.93010680632845, 20.14871993892883, 23.34701823947476, 23.074885613557637, 26.516561705994132, 24.588018503392004, 24.199568150502767, 26.889586488545557, 27.93301868482534, 29.027805842817497, 29.34873805170069, 30.120835580459396, 29.566379601974074, 28.044669108206943, 24.36396223902248, 26.090572115980887, 26.609655786900685, 21.915151352804752], "xaxis": "x", "xbins": {"end": 30.120835580459396, "size": 1.0, "start": 5.114965165581406}, "yaxis": "y"}, {"autobinx": false, "histnorm": "probability density", "legendgroup": "Current", "marker": {"color": "#ed0400"}, "name": "Current", "opacity": 0.7, "type": "histogram", "x": [9.088446005125856, 8.956787646042581, 9.20545555460063, 9.65001825939937, 11.57818249538131, 10.768167212254763, 9.472682201680879, 14.955413165215628, 13.738857994842686, 14.550831648226602, 12.769112339073143, 14.039860153077836, 12.470143559854403, 13.845977111059948, 17.101304041076002, 21.957200684965795, 21.607731557485646, 20.653680305390065, 20.66839844803452, 23.46428117610851, 21.607827400992203, 20.93334640468886, 14.501457906094924, 15.498062671991658, 18.12194077571844, 14.402451100497085, 12.143842225082135], "xaxis": "x", "xbins": {"end": 23.46428117610851, "size": 1.0, "start": 8.956787646042581}, "yaxis": "y"}, {"legendgroup": "Reference", "marker": {"color": "#4d4d4d"}, "mode": "lines", "name": "Reference", "showlegend": false, "type": "scatter", "x": [5.114965165581406, 5.164976906411162, 5.214988647240918, 5.265000388070674, 5.31501212890043, 5.365023869730186, 5.415035610559942, 5.465047351389698, 5.515059092219454, 5.56507083304921, 5.615082573878966, 5.665094314708722, 5.715106055538477, 5.765117796368234, 5.81512953719799, 5.865141278027746, 5.915153018857501, 5.965164759687258, 6.015176500517014, 6.065188241346769, 6.1151999821765255, 6.165211723006282, 6.215223463836038, 6.265235204665793, 6.3152469454955495, 6.365258686325306, 6.415270427155062, 6.465282167984817, 6.515293908814574, 6.56530564964433, 6.615317390474085, 6.665329131303841, 6.715340872133598, 6.765352612963353, 6.815364353793109, 6.86537609462286 ...

# %%
weather_target_drift_report.save("gdrive/MyDrive/ModelMonitoringBlog/reports/2020_weather_TARGET_report.html")

# %% [markdown]
# From here, I think we're good to write up about the experience, pausing for now.
